# %% [markdown]
# # 🌋 Compilador de APK en la Nube - Alarma Antisísmica con Python
# Ejecuta estas celdas paso a paso en **Google Colab** para obtener tu archivo `.apk` listo para instalar en tu teléfono Android sin necesidad de instalar SDKs pesados en tu computadora.

# %% [markdown]
# ### 1. Instalar dependencias del sistema y Buildozer

# %%
# !sudo apt update
# !sudo apt install -y git zip unzip openjdk-17-jdk autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip install --upgrade pip
# !pip install Cython==0.29.36 buildozer virtualenv

# %% [markdown]
# ### 2. Generar el sonido de la sirena y verificar archivos

# %%
# !python siren_generator.py
# !ls -la

# %% [markdown]
# ### 3. Compilar el APK con Buildozer (Auto-confirmación)

# %%
# !yes | buildozer -v android debug

# %% [markdown]
# ### 4. Descargar el archivo APK generado a tu computadora o móvil

# %%
from google.colab import files
import glob

apk_files = glob.glob('bin/*.apk')
if apk_files:
    print(f'Descargando: {apk_files[0]}')
    files.download(apk_files[0])
else:
    print('No se encontró el APK en la carpeta bin/')
